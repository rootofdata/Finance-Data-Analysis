# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm

# %%
#글씨설정
plt.rc("font",family="Malgun Gothic")
sns.set(font="Margun Gothic",rc={"axes.unicode_minus":False},style='darkgrid')
mpl.rc('font',family='Malgun Gothic')
plt.rcParams['axes.unicode_minus']=False

#맷플롯립 한글 설정
font_path = r'C:\Users\dudtj\OneDrive\Desktop\금융데이터\NanumFontSetup_TTF_ALL'
fontprop = fm.FontProperties(fname=font_path, size=18)

# %%
data = pd.read_csv(r'C:\Users\dudtj\OneDrive\Desktop\python\금융데이터\금융보안원_경진대회_데이터(최종제출)1.csv',encoding='euc-kr')

# %%
#매출금액 단위 만원으로 변환 
data['매출금액'] = data['매출금액']/10000
data.rename(columns={'매출금액' : '매출금액(단위:만원)'}, inplace=True)

# %%
import matplotlib.pyplot as plt
data.품목대분류명.count
# Out:
# <bound method Series.count of 0              의류
# 1         e상품/서비스
# 2           출산/육아
# 3         e상품/서비스
# 4              생활
#            ...
# 519292     여가/스포츠
# 519293    e상품/서비스
# 519294       패션잡화
# 519295         식품
# 519296    e상품/서비스
# Name: 품목대분류명, Length: 519297, dtype: object>

# %%
data[data['품목대분류명'] == '인테리어']
# Out:
#           기준년월  품목대분류코드 품목대분류명  품목중분류코드    품목중분류명  성별   연령   가구생애주기  \
# 72      201903       14   인테리어     1410     침구/수예  여성  40대  초중고자녀가구
# 149     201903       14   인테리어     1410     침구/수예  남성  40대  초중고자녀가구
# 150     201903       14   인테리어     1412  DIY자재/용품  여성  40대  초중고자녀가구
# 161     201903       14   인테리어     1410     침구/수예  여성  30대  신혼영유아가구
# 175     201903       14   인테리어     1412  DIY자재/용품  여성  40대  초중고자녀가구
# ...        ...      ...    ...      ...       ...  ..  ...      ...
# 519174  202103       14   인테리어     1410     침구/수예  여성  50대   성인자녀가구
# 519177  202103       14   인테리어     1411    인테리어소품  남성  20대     1인가구
# 519182  202103       14   인테리어     1410     침구/수예  남성  30대  신혼영유아가구
# 519189  202103       14   인테리어     1410     침구/수예  남성  50대   성인자녀가구
# 519256  202103       14   인테리어     1412  DIY자재/용품  여성  40대  초중고자녀가구
#
#        고객소재지_광역시도 고객소재지_시군구 고객소재지_읍면동  매출금액(단위:만원)  매출건수
# 72          서울특별시       양천구        목동     747.6484   125
# 149           경기도       용인시        중동      38.7646    17
# 150           경기도       용인시        중동      40.6394    17
# 161           경기도       용인시        중동     266.4583    50
# 175         서울특별시       도봉구        창동      14.1037    17
# ...           ...       ...       ...          ...   ...
# 519174        경기도       수원시      오목천동      33.1781     9
# 519177      서울특별시       용산구      이태원동       6.9915     5
# 519182        경기도       고양시      정발산동      27.7483     7
# 519189        경기도       용인시      풍덕천동      32.5210     7
# 519256      서울특별시      영등포구     양평동3가      42.4525     5
#
# [20053 rows x 13 columns]

# %%
data.loc[(data.품목대분류명=='인테리어'),'품목대분류명']='기타'
data.loc[(data.품목대분류명=='가구'),'품목대분류명']='기타'
data.loc[(data.품목대분류코드=='13'),'품목대분류코드']='99'
data.loc[(data.품목대분류코드=='14'),'품목대분류코드']='99'

# %%
data[data['품목대분류명'] == '기타']
# Out:
#           기준년월 품목대분류코드 품목대분류명  품목중분류코드    품목중분류명  성별   연령   가구생애주기 고객소재지_광역시도  \
# 18      201903      99     기타     9911      기타결제  남성  30대  신혼영유아가구      서울특별시
# 32      201903      13     기타     1314        기타  여성  30대  신혼영유아가구      서울특별시
# 40      201903      13     기타     1314        기타  여성  30대  신혼영유아가구      서울특별시
# 42      201903      13     기타     1313     테이블가구  여성  20대     1인가구      서울특별시
# 72      201903      14     기타     1410     침구/수예  여성  40대  초중고자녀가구      서울특별시
# ...        ...     ...    ...      ...       ...  ..  ...      ...        ...
# 519182  202103      14     기타     1410     침구/수예  남성  30대  신혼영유아가구        경기도
# 519189  202103      14     기타     1410     침구/수예  남성  50대   성인자녀가구        경기도
# 519194  202103      99     기타     9911      기타결제  남성  20대     1인가구        경기도
# 519195  202103      13     기타     1314        기타  여성  30대  신혼영유아가구      서울특별시
# 519256  202103      14     기타     1412  DIY자재/용품  여성  40대  초중고자녀가구      서울특별시
#
#        고객소재지_시군구 고객소재지_읍면동  매출금액(단위:만원)  매출건수
# 18           강동구        길동      62.3266    63
# 32           광진구        능동      67.7879    13
# 40           양천구        목동      44.7334    13
# 42           양천구        목동      43.9913    13
# 72           양천구        목동     747.6484   125
# ...          ...       ...          ...   ...
# 519182       고양시      정발산동      27.7483     7
# 519189       용인시      풍덕천동      32.5210     7
# 519194       성남시      하대원동       3.5363     7
# 519195       성북구      하월곡동      35.7127     7
# 519256      영등포구     양평동3가      42.4525     5
#
# [45296 rows x 13 columns]

# %%
grouped = data['매출금액(단위:만원)'].groupby(data['품목대분류명']).sum()
df_g = pd.DataFrame(grouped)
df_g=df_g.sort_values(by=['매출금액(단위:만원)'])

# %%
data['매출금액(단위:만원)'].groupby(data['품목대분류명']).sum().index
# Out:
# Index(['e상품/서비스', '건강', '기타', '뷰티', '생활', '식품', '여가/스포츠', '의류', '전자', '출산/육아',
#        '패션잡화'],
#       dtype='object', name='품목대분류명')

# %%
data['매출금액(단위:만원)'].groupby(data['품목대분류명']).sum().index## 라벨
# Out:
# Index(['e상품/서비스', '건강', '기타', '뷰티', '생활', '식품', '여가/스포츠', '의류', '전자', '출산/육아',
#        '패션잡화'],
#       dtype='object', name='품목대분류명')

# %%
data['매출금액(단위:만원)'].groupby(data['품목대분류명']).sum() ## 빈도
# Out:
# 품목대분류명
# e상품/서비스    4.541755e+07
# 건강         4.943765e+06
# 기타         4.170706e+06
# 뷰티         3.251842e+06
# 생활         5.858030e+06
# 식품         1.029924e+07
# 여가/스포츠     1.486947e+07
# 의류         5.319929e+06
# 전자         9.269736e+06
# 출산/육아      5.897862e+06
# 패션잡화       4.347801e+06
# Name: 매출금액(단위:만원), dtype: float64

# %%
import matplotlib.pyplot as plt
import numpy as np

## 데이터 준비
colors = sns.color_palette('hls',len(labels)) ## 색상
labels = data['매출금액(단위:만원)'].groupby(data['품목대분류명']).sum().index## 라벨
frequency =data['매출금액(단위:만원)'].groupby(data['품목대분류명']).sum() ## 빈도
 
## 데이터 라벨, 빈도수, 색상을 빈도수를 기준으로 정렬해야한다.
labels_frequency = zip(labels,frequency,colors) 
labels_frequency = sorted(labels_frequency,key=lambda x: x[1],reverse=True)
 
sorted_labels = [x[0] for x in labels_frequency] ## 정렬된 라벨
sorted_frequency = [x[1] for x in labels_frequency] ## 정렬된 빈도수
sorted_colors = [x[2] for x in labels_frequency] ## 정렬된 색상
 
fig = plt.figure(figsize=(12,12)) ## 캔버스 생성
fig.set_facecolor('white') ## 캔버스 배경색을 하얀색으로 설정
ax = fig.add_subplot() ## 프레임 생성

pie = ax.pie(sorted_frequency, ## 파이차트 출력
       labels=sorted_labels,
       startangle=90, ## 시작점을 90도(degree)로 지정
       counterclock=False, ## 시계방향으로 그려짐
       colors = sorted_colors,
       autopct= '%1.1f%%' ## 색상 지정
       )

plt.legend(pie[0],sorted_labels,loc='upper right',fontsize=9,edgecolor='k') ## 범례
plt.show()

####인테리어 가구 기타
# Out:
# findfont: Font family ['NanumGothicExtraBold'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['NanumGothicExtraBold'] not found. Falling back to DejaVu Sans.

# %%
#### 소비와 주가를 연관시켜보자

# %%
data_L_M = data[(data.품목대분류명 =='여가/스포츠')|(data.품목대분류명 =='전자')|(data.품목대분류명 =='식품')|(data.품목대분류명 =='e상품/서비스')]
data_L_M
# Out:
#           기준년월 품목대분류코드   품목대분류명  품목중분류코드   품목중분류명  성별      연령   가구생애주기  \
# 1       201903      21  e상품/서비스     2110   o2o서비스  여성     20대  신혼영유아가구
# 3       201903      21  e상품/서비스     2111  e머니/상품권  여성     30대  신혼영유아가구
# 8       201903      15       전자     1510       가전  여성     20대     1인가구
# 10      201903      20   여가/스포츠     2013       여행  남성     40대  신혼영유아가구
# 12      201903      15       전자     1511      디지털  남성     40대  신혼영유아가구
# ...        ...     ...      ...      ...      ...  ..     ...      ...
# 519287  202103      21  e상품/서비스     2110   o2o서비스  여성  60대 이상     노인가구
# 519292  202103      20   여가/스포츠     2013       여행  여성     30대     1인가구
# 519293  202103      21  e상품/서비스     2110   o2o서비스  남성     30대     1인가구
# 519295  202103      16       식품     1610     가공식품  남성     40대  초중고자녀가구
# 519296  202103      21  e상품/서비스     2110   o2o서비스  여성  60대 이상     노인가구
#
#        고객소재지_광역시도 고객소재지_시군구 고객소재지_읍면동  매출금액(단위:만원)  매출건수
# 1           서울특별시       구로구        궁동      96.3789    29
# 3           서울특별시       구로구        궁동     108.9360    54
# 8           서울특별시       강동구        길동     242.9276    17
# 10          서울특별시       강동구        길동     111.9710    17
# 12          서울특별시       강동구        길동     252.5664    17
# ...           ...       ...       ...          ...   ...
# 519287      서울특별시       성북구    동소문동7가      38.5208     7
# 519292      서울특별시      영등포구    영등포동7가     141.1368     7
# 519293      서울특별시      영등포구    영등포동7가     138.6040    63
# 519295      서울특별시      영등포구    영등포동7가      32.7592     7
# 519296      서울특별시      영등포구    영등포동8가      92.6404    10
#
# [241726 rows x 13 columns]

# %%
grouped_L_M = data_L_M['매출금액'].groupby(data_L_M['품목대분류명']).sum()
df_g_L_M = pd.DataFrame(grouped_L_M)
df_g_L_M
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '매출금액'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-400-49e2a12757d5> in <module>
# ----> 1 grouped_L_M = data_L_M['매출금액'].groupby(data_L_M['품목대분류명']).sum()
#       2 df_g_L_M = pd.DataFrame(grouped_L_M)
#       3 df_g_L_M
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: '매출금액'

# %%
df_g_L_M.rename(columns={'매출금액':'매출합계'}, inplace = True)
df_g_L_M.reset_index(inplace=True)
df_g_L_M.rename(columns= {'품목대분류명' : 'largecategory', '매출합계' : 'Total'}, inplace= True)
df_g_L_M
# Out:
#    largecategory         Total
# 0        e상품/서비스  4.541755e+07
# 1             가구  1.276486e+06
# 2             건강  4.943765e+06
# 3             기타  1.012914e+06
# 4             뷰티  3.251842e+06
# 5             생활  5.858030e+06
# 6             식품  1.029924e+07
# 7         여가/스포츠  1.486947e+07
# 8             의류  5.319929e+06
# 9           인테리어  1.881305e+06
# 10            전자  9.269736e+06
# 11         출산/육아  5.897862e+06
# 12          패션잡화  4.347801e+06

# %%
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['font.size'] = 23
plt.rcParams['figure.figsize'] = (10, 8)

# %%
fig, ax = plt.subplots(1, 1, figsize = (10, 8))
sns.barplot(x = 'largecategory', y = 'Total', data = df_g_L_M)
fig.autofmt_xdate(rotation = 45)

# %%
data_L_C = data_df[['품목대분류명', '매출건수']]
data_L_C
# Out:
#          품목대분류명  매출건수
# 0            의류    13
# 1       e상품/서비스    29
# 2         출산/육아    46
# 3       e상품/서비스    54
# 4            생활    58
# ...         ...   ...
# 519292   여가/스포츠     7
# 519293  e상품/서비스    63
# 519294     패션잡화     7
# 519295       식품     7
# 519296  e상품/서비스    10
#
# [519297 rows x 2 columns]

# %%
grouped_L_C = data_L_C['매출건수'].groupby(data_L_C['품목대분류명']).sum()
df_L_C = pd.DataFrame(grouped_L_C);df_L_C
# Out:
#              매출건수
# 품목대분류명
# e상품/서비스  12109299
# 가구         135554
# 건강         890922
# 기타         291332
# 뷰티         801723
# 생활        1604069
# 식품        2904327
# 여가/스포츠    2388971
# 의류         901036
# 인테리어       334541
# 전자         959948
# 출산/육아     1397660
# 패션잡화       704807

# %%
df_L_C.reset_index(inplace=True)
df_L_C.rename(columns={'품목대분류명':'largecategory', '매출건수':'Total'}, inplace=True)
df_L_C
# Out:
#    largecategory     Total
# 0        e상품/서비스  12109299
# 1             가구    135554
# 2             건강    890922
# 3             기타    291332
# 4             뷰티    801723
# 5             생활   1604069
# 6             식품   2904327
# 7         여가/스포츠   2388971
# 8             의류    901036
# 9           인테리어    334541
# 10            전자    959948
# 11         출산/육아   1397660
# 12          패션잡화    704807

# %%
fig, ax = plt.subplots(1, 1, figsize = (10, 8))
sns.barplot(x = 'largecategory', y = 'Total', data = df_L_C)
fig.autofmt_xdate(rotation = 45)

# %%
data_L_M.set_index('기준년월', inplace=True)

# %%
data_L_M
# Out:
#          품목대분류명      매출금액
# 기준년월
# 201903       의류   78.2521
# 201903  e상품/서비스   96.3789
# 201903    출산/육아   92.4309
# 201903  e상품/서비스  108.9360
# 201903       생활  165.6740
# ...         ...       ...
# 202103   여가/스포츠  141.1368
# 202103  e상품/서비스  138.6040
# 202103     패션잡화   39.0818
# 202103       식품   32.7592
# 202103  e상품/서비스   92.6404
#
# [519297 rows x 2 columns]

# %%
df_L_M1903 = data_L_M.loc[201903]
df_L_M1909 = data_L_M.loc[201909]
df_L_M2003 = data_L_M.loc[202003]
df_L_M2009 = data_L_M.loc[202009]
df_L_M2103 = data_L_M.loc[202103]

# %%
dfset = [df_L_M1903, df_L_M1909, df_L_M2003, df_L_M2009, df_L_M2103]
for df in dfset:
    df.rename(columns={'매출금액':'매출합계'}, inplace = True)
    df.reset_index(inplace=True)
    df.rename(columns= {'품목대분류명' : 'largecategory', '매출합계' : 'Total_Money'}, inplace= True)
# Out:
# C:\Users\dudtj\anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df_L_M1903
# Out:
#          기준년월 largecategory  Total_Money
# 0      201903            의류      78.2521
# 1      201903       e상품/서비스      96.3789
# 2      201903         출산/육아      92.4309
# 3      201903       e상품/서비스     108.9360
# 4      201903            생활     165.6740
# ...       ...           ...          ...
# 68256  201903            의류     126.0455
# 68257  201903         출산/육아     289.4378
# 68258  201903       e상품/서비스    1327.6210
# 68259  201903        여가/스포츠      22.3538
# 68260  201903            의류      83.5484
#
# [68261 rows x 3 columns]

# %%
dfLM = data_df[['기준년월', '품목대분류명','품목중분류명','매출금액']]
dfLM
# Out:
#           기준년월   품목대분류명   품목중분류명      매출금액
# 0       201903       의류     여성의류   78.2521
# 1       201903  e상품/서비스   o2o서비스   96.3789
# 2       201903    출산/육아  육아용품서비스   92.4309
# 3       201903  e상품/서비스  e머니/상품권  108.9360
# 4       201903       생활     생활용품  165.6740
# ...        ...      ...      ...       ...
# 519292  202103   여가/스포츠       여행  141.1368
# 519293  202103  e상품/서비스   o2o서비스  138.6040
# 519294  202103     패션잡화   시계/주얼리   39.0818
# 519295  202103       식품     가공식품   32.7592
# 519296  202103  e상품/서비스   o2o서비스   92.6404
#
# [519297 rows x 4 columns]

# %%
def get_barplot_M(category):
    dfLM_bar = dfLM[dfLM['품목대분류명'] == category]
    sns.barplot(x = '품목중분류명', y = '매출금액', hue = '기준년월', data = dfLM_bar)

# %%
get_barplot_M('전자')

# %%
get_barplot_M('여가/스포츠')

# %%
get_barplot_M('식품')

# %%
get_barplot_M('e상품/서비스')

# %%
def get_barplot_C(category):
    dfLC = data_df[['기준년월', '품목대분류명','품목중분류명','매출건수']]
    dfLC
    dfLC_bar = dfLC[dfLC['품목대분류명'] == category]
    sns.barplot(x = '품목중분류명', y = '매출건수', hue = '기준년월', data = dfLC_bar)

# %%
get_barplot_C('전자')

# %%
get_barplot_C('e상품/서비스')

# %%
get_barplot_C('여가/스포츠')

# %%
get_barplot_C('식품')

# %%
get_barplot_M('의류')

# %%
get_barplot_M('생활')

# %%
get_barplot_M('뷰티')

# %%
get_barplot_M('건강')

# %%
get_barplot_M('패션잡화')

# %%
get_barplot_M('인테리어')

# %%
get_barplot_M('출산/육아')

# %%
get_barplot_M('가구')

# %%
df_e = dfLM[dfLM['품목대분류명'] == 'e상품/서비스']
grouped_e = pd.DataFrame(df_e['매출금액'].groupby(df_e['기준년월']).sum())
grouped_e
# Out:
#                 매출금액
# 기준년월
# 201903  7.020302e+06
# 201909  7.255877e+06
# 202003  9.464159e+06
# 202009  1.003509e+07
# 202103  1.164213e+07

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(grouped_e, 'ko--')
ax.set_xticks([201903, 201909, 202003, 202009, 202103])
# Out:
# [<matplotlib.axis.XTick at 0x24f2594ff40>,
#  <matplotlib.axis.XTick at 0x24f2594fdc0>,
#  <matplotlib.axis.XTick at 0x24f29053790>,
#  <matplotlib.axis.XTick at 0x24f2852ecd0>,
#  <matplotlib.axis.XTick at 0x24f2852ea00>]

# %%
df_e.drop('품목중분류명', axis=1, inplace=True)
df_e
# Out:
# C:\Users\dudtj\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           기준년월   품목대분류명      매출금액
# 1       201903  e상품/서비스   96.3789
# 3       201903  e상품/서비스  108.9360
# 16      201903  e상품/서비스  100.6313
# 23      201903  e상품/서비스  153.1532
# 24      201903  e상품/서비스  156.2958
# ...        ...      ...       ...
# 519280  202103  e상품/서비스   55.3418
# 519281  202103  e상품/서비스   72.0728
# 519287  202103  e상품/서비스   38.5208
# 519293  202103  e상품/서비스  138.6040
# 519296  202103  e상품/서비스   92.6404
#
# [76052 rows x 3 columns]

# %%
#box plot
sns.factorplot( x = '기준년월', y = '매출금액', kind = 'box', data = df_e)
# Out:
# C:\Users\dudtj\anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
