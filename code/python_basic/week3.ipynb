# %%
#1.

#number은 종목번호에 대한 리스트이고, 
#name은 종목명과 주가 정보가 튜플형태로 되어있는 리스트입니다

number = ['005930', '035720', '000660','035420']
name = [('삼성',70000), ('카카오',140000), ('SK하이닉스',100000), ('네이버',430000)]

stock_dic= dict(zip(number,name))

# %% [markdown]
# 1-1.  number, name 리스트를 사용하여  딕셔너리 만들어보기(zip함수 사용!)

# %% [markdown]
# 이와 같이 출력
#
# {'005930': ('삼성', 70000), '035720': ('카카오', 140000), '000660': ('SK하이닉스', 100000), '035420': ('네이버', 430000)}

# %%
#1-1 1-2. 1-1에서 만든 딕셔너리를 이용하여 enummerate 사용해보기(for , items() 사용!)
stock_dic
# Out:
# {'005930': ('삼성', 70000),
#  '035720': ('카카오', 140000),
#  '000660': ('SK하이닉스', 100000),
#  '035420': ('네이버', 430000)}

# %%
for index,(name,value) in enumerate(stock_dic.items()):
    print(index,name,value)
# Out:
# 0 005930 ('삼성', 70000)
# 1 035720 ('카카오', 140000)
# 2 000660 ('SK하이닉스', 100000)
# 3 035420 ('네이버', 430000)

# %% [markdown]
# 1-3.  listcomprehension 사용해보기
# 1-2에서 만든 enummerate문을 이용하여 딕셔너리의 인덱스가 짝수번째인 value만 출력(for, enummerate, items(), if 사용!)

# %% [markdown]
# #이와 같이 출력
#
# [('삼성', 70000), ('SK하이닉스', 100000)]

# %%
b=[]
for index,(name,value) in enumerate(stock_dic.items()):
    if(index % 2)==0:
        b+=value
b
# Out:
# ['삼성', 70000, 'SK하이닉스', 100000]

# %% [markdown]
# #Quiz 2
#
# list comprehension과 큐(queue)를 활용한 solution함수를 만들어 봅시다!
#
# 인쇄 요청이 들어온 순서대로 인쇄하는 일반적인 프린터와 다르게, 중요도가 높은 문서를 먼저 인쇄하는 프린터가 개발됐습니다. 이 프린터는 아래와 같은 방식으로 인쇄 작업을 수행합니다.
#
# 1. 인쇄 대기목록의 가장 앞에 있는 문서(J)를 대기목록에서 꺼냅니다.
# 2. 나머지 인쇄 대기목록에서 J보다 중요도가 높은 문서가 한 개라도 존재하면 J를 대기목록의 가장 마지막에 넣습니다.
# 3. 그렇지 않으면 J를 인쇄합니다.
#
# 예를 들어, 4개의 문서(A, B, C, D)가 순서대로 인쇄 대기목록에 있고 중요도가 2 1 3 2 라면 C D A B 순으로 인쇄하게 됩니다.
#
# **현재 대기목록에 있는 문서의 중요도가 순서대로 담긴 배열 priorities와 내가 인쇄를 요청한 문서가 현재 대기목록의 어떤 위치에 있는지를 알려주는 location이 매개변수로 주어질 때, 내가 인쇄를 요청한 문서가 몇 번째로 인쇄되는지 return 하도록 solution 함수를 작성해주세요**.
#
# - 현재 대기목록에는 1개 이상 100개 이하의 문서가 있습니다.
# - 인쇄 작업의 중요도는 1~9로 표현하며 숫자가 클수록 중요하다는 뜻입니다.
# - location은 0 이상 (현재 대기목록에 있는 작업 수 - 1) 이하의 값을 가지며 대기목록의 가장 앞에 있으면 0, 두 번째에 있으면 1로 표현합니다.

# %% [markdown]
# #예시1
# priorities = [2, 1, 3, 2]
# location = 2
#
# solution(priorities, location)
# #output
# 1
#
# #예시2
# priorities = [1, 1, 9, 1, 1, 1]
# location = 0
#
# solution(priorities, location)
# #output
# 5

# %%
from collections import deque

# %%
answer = 0
priorities = [2, 1, 3, 2]
queue = [i for i in enumerate(priorities)]
queue
# Out:
# [(0, 2), (1, 1), (2, 3), (3, 2)]

# %%
def solution(priorities,location):
    ans = 0
    queue = [i for i in enumerate(priorities)]
    while True:
        a = queue[0]
        if a[1] ==max([v[1] for v in queue]):
            ans += 1
            if a[0] == location:
                return ans
            else:
                queue.pop(0)
        else:
            queue.append(a)
            queue.pop(0)
    return ans

# %%
priorities = [2, 1, 3, 2]
location = 2

solution(priorities, location)
# Out:
# 1

# %% [markdown]
# 서브프라임 당시의 kospi  최대 손실 낙폭(MDD) 구하기
# - 최대 손실 낙폭(MDD) :특정 기간 동안 최대한 얼마의 손실이 날 수 있는지를 판단하는 지표

# %%
#3
import FinanceDataReader as fdr
import pandas as pd

# KOSPI지수 데이터 가져오기 (2004년 ~ 2020년)
kospi_df = fdr.DataReader('KS11', '2004-01-04', '2020-12-31')
kospi_df.head()
# Out:
# /Users/seoyoungsuk/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2004-01-05  817.280029  825.429993  816.549988  824.099976  824.099976
# 2004-01-06  831.260010  831.260010  819.530029  823.429993  823.429993
# 2004-01-07  826.080017  831.070007  825.229980  827.070007  827.070007
# 2004-01-08  831.099976  839.280029  824.150024  824.150024  824.150024
# 2004-01-09  835.419983  849.500000  835.049988  845.270020  845.270020
#
#               Volume
# Date
# 2004-01-05  408300.0
# 2004-01-06  484100.0
# 2004-01-07  404600.0
# 2004-01-08  428800.0
# 2004-01-09  543300.0

# %%
# 1년기간 동안 최고치 구하기 (1년 동안의 개장일을 252일로 가정)
peak = kospi_df['Close'].rolling(window=252, min_periods=1).max()

# 최고치 대비 현재 kospi 종가의 하락정도
drawdown = kospi_df['Close']/peak - 1.0

# 최대손실 낙폭
max_drawdown = drawdown.rolling(window=252, min_periods=1).min()
max_drawdown
# Out:
# Date
# 2004-01-05    0.000000
# 2004-01-06   -0.000813
# 2004-01-07   -0.000813
# 2004-01-08   -0.003531
# 2004-01-09   -0.003531
#                 ...
# 2020-12-23   -0.357089
# 2020-12-24   -0.357089
# 2020-12-28   -0.357089
# 2020-12-29   -0.357089
# 2020-12-30   -0.357089
# Name: Close, Length: 4236, dtype: float64

# %% [markdown]
# 3-1. MDD와 MDD를 기록한 기간을 구해주세요.

# %%
MDD_min = max_drawdown.min
max_drawdown[max_drawdown==MDD_min()]
# Out:
# Date
# 2008-10-24   -0.545367
# 2008-10-27   -0.545367
# 2008-10-28   -0.545367
# 2008-10-29   -0.545367
# 2008-10-30   -0.545367
#                 ...
# 2009-10-14   -0.545367
# 2009-10-15   -0.545367
# 2009-10-16   -0.545367
# 2009-10-19   -0.545367
# 2009-10-20   -0.545367
# Name: Close, Length: 252, dtype: float64

# %% [markdown]
# 3-2. enumerate를 활용하여 아래 규칙에 맞게 데이터를 넣어주세요.
#
# MDD를 기록한 기간에는 1, 그렇지 않으면 0을 kospi_df 데이터프레임의 'max_drawdown' 컬럼에  넣어주세요.

# %%
# kospi_df 데이터프레임에 'max_drawdown'컬럼을 추가한 후 진행
kospi_df['max_drawdown'] = max_drawdown
col = len(kospi_df.columns) - 1

# %%
for i,v in enumerate(kospi_df.max_drawdown):
    if v == MDD_min: 
        kospi_df.iloc[i,col]=1
    else: 
        kospi_df.iloc[i,col]=0

kospi_df[kospi_df.max_drawdown ==1]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume, max_drawdown]
# Index: []

# %%
for i,v in enumerate(kospi_df.max_drawdown):
    if v == MDD_min: 
        kospi_df.max_drawdown[i]=1
    else: 
        kospi_df.max_drawdown[i]=0

kospi_df[kospi_df.max_drawdown ==1]
# Out:
# /var/folders/0s/_hvvlnsj5gd43ym4gdrnqwj80000gn/T/ipykernel_17292/2960514379.py:5: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   kospi_df.max_drawdown[i]=0
# /var/folders/0s/_hvvlnsj5gd43ym4gdrnqwj80000gn/T/ipykernel_17292/2960514379.py:5: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   kospi_df.max_drawdown[i]=0
# ...

# %% [markdown]
# Why Do Most Investors Choose Concentration Over Leverage?
#
# https://www.aqr.com/Insights/Research/Alternative-Thinking/Why-Do-Most-Investors-Choose-Concentration-Over-Leverage

# %% [markdown]
# 문제1)
#
#  벤저민 그레이엄은 그의 전설적인 저서 <현명한 투자자(1949)>에서 현명한 투자자를 위한 주식과 채권의 자산배분에 대하여 다음과 같이 말했습니다.
#
# > Investors should never have less than 25% or more than 75% of his funds in common stocks.
#
#  높은 수익을 원하는 투자자 A는 그레이엄의 말을 따라 미국 주식에 75%, 10년 만기 미국채에 25%를 투자하기로 하였습니다. classic_investor 딕셔너리에 "A"를 key로 갖고 1928년 초부터 2020년말까지 A의 포트폴리오 전략을 고수했을 때 얻게 되는 수익을 리스트 형태의 value로 갖도록 추가하세요(이때 위에 제시된 classic_investor 딕셔너리와 **파이썬의 내장함수 zip**을 이용하세요).

# %%
import numpy as np
A=np.array([[0.75,0.25]])

invest=[[s,b]for s,b in zip(classic_investor['stock'],classic_investor['bond'])]

invest=np.array(invest)
invest

# %%
returni=A.T@invest
dic=dict()
dic['A']=returni
dic
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 returni=A.T@invest
#       2 dic=dict()
#       3 dic['A']=returni
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 93 is different from 1)

# %% [markdown]
# 문제2)
#
#  수익률과 수익률의 변동성을 모두 고려하는 투자자 B는 주식에 39.382139%, 채권에 60.617861% 만큼을 투자하는 것이 좋겠다는 생각을 했습니다. classic_investor 딕셔너리에 "B"를 key로 갖고 1928년 초부터 2020년말까지 B의 포트폴리오 비율을 고수했을 때 얻게 되는 수익을 리스트 형태의 value로 갖도록 추가하세요(이때 위에 제시된 classic_investor 딕셔너리와 **파이썬의 내장함수 zip**을 이용하세요).

# %% [markdown]
# 문제3)
#
#  B의 자산배분 비율에 큰 감명을 받은 C는 B의 비율대로 주식과 채권에 자산을 배분하기로 했습니다. 그런데 C는 그 비율대로 투자했을 때 A보다 낮은 수익률을 얻는다는 사실이 마음에 들지 않습니다. 이에 C는 레버리지를 이용해 수익률을 높여야 겠다고 생각합니다. C는 적절한 레버리지 비율을 (0.14947946831105105 / 0.09062961032744317) 로 정했습니다. 이를 레버리지 상수라고 부르기로 하고, 이 레버리지 상수를 요소로 갖고 길이가 93인 리스트를 **리스트 컴프리헨션**을 이용하여 만들고, classic_investor 딕셔너리에 "C"를 key로 갖고 1928년 초부터 2020년말까지 C의 자산배분 비율과 레버리지를 고수했을 때 얻게 되는 수익을 리스트 형태의 value로 갖도록 추가하세요(이때 위에 제시된 classic_investor 딕셔너리와 **파이썬의 내장함수 zip**을 이용하세요).

# %%
const=0.14947946831105105 / 0.09062961032744317
leveraging=[[const] for i in range(93)]
returni=leveraging*invest@B.T

dic['C']=returni
dic['C']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 5
#       2 leveraging=[[const] for i in range(93)]
#       3 returni=leveraging*invest@B.T
# ----> 5 dic['C']=returni
#       6 dic['C']
#
# NameError: name 'dic' is not defined

# %% [markdown]
# 문제4)
# https://findagroup.notion.site/image/https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fsecure.notion-static.com%2F76e0045f-8229-4c3e-a7b6-9b5314db304f%2FUntitled.png?table=block&id=f8c75623-bb90-4926-b7ae-665e762c3b81&spaceId=547ebec4-0ece-437d-9561-407ea853b165&width=1920&userId=&cache=v2
#  위 그림의 x축은 연간 수익률의 표준편차, y축은 연간 수익률의 평균입니다.
#  세 투자자들(A,B and C)의 1928년부터 2020년까지의 포트폴리오 수익률 평균과 표준편차를 계산하여 위 좌표평면에 표시해보세요. (파이썬을 통해 plotting 하는 문제가 아닙니다. 그냥 그림에 표시만 해보시면 됩니다!)
#  수익률의 표준편차를 위험으로 정의한다면 세 투자자의 좌표평면 상 위치는 어떤 의미를 가지나요?

# %%
A_mean=dic['A'].mean
B_mean=dic['B'].mean
C_mean=dic['C'].mean
A_std=dic['A'].std
B_std=dic['B'].std
C_std=dic['C'].std

# %% [markdown]
# 문제5)
#
#  대부분의 투자자들은 C의 방식(분산 후 레버리지)보다는 A의 방식(집중)으로 투자한다고 합니다. 왜 대부분의 투자자들은 그런 선택을 하는 것일까요? 다음에서 합당해보이는 이유를 **모두 골라주세요.** 보기에 없는 이유를 생각해보셔도 좋습니다!
#
# a) 실제 투자 세계에서는 차입 제약이 있기 때문이다(선물 증거금, 차입비용 등).
#
# b) 투자자들이 레버리지를 사용하는 것에서 수익률의 표준편차로 설명되지 않는 위험을 느끼기 때문이다(leverage-aversion).
#
# c) 레버리지를 사용하는 것보다는 집중 투자하는 것이 더 전통적(conventional)이고 친숙(familiar)하기 때문이다.
#
# d) 투자자들이 특정 자산군 수익률에 대한 자신의 예측 능력을 과대평가하기 때문이다.

# %% [markdown]
# d 실질적인 방식보다 눈에 보이는 방식이 더 낫다고 생각해서?
